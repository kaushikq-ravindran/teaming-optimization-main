# %%
import networkx as nx
import numpy as np
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
graph1 = nx.complete_graph(26)

graph1.remove_edge(0,1)
graph1.remove_edge(7,5)
graph1.remove_edge(6,8)
graph1.remove_edge(6,7)

nx.draw_circular(graph1, node_size=500, with_labels=True)
